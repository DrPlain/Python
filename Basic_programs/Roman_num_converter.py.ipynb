# %%
def roman_to_num_converter(roman=""):
    all_roman_set = {'I', 'V','X','L','C','D','M'}
    all_roman_dict = {'I':1, 'V':5,'X':10,'L':50,'C':100,'D':500,'M':1000}
    
    if not isinstance(roman, str):
        return "Invalid input"
    if roman == "":
        return "Empty string"
    roman = roman.strip().upper()
    roman_dup = roman[:]
    if set(roman).issubset(all_roman_set) == False:
        return "Invalid input"
    
    for key in all_roman_dict:
        if list(set(roman))[0] == key or roman == key:
            '''cases were input is key roman numeral or invalid input
            where a key numeral is repeated more than 3 times'''
            if len(roman) <= len(key*3):
                return all_roman_dict[key]
            else:
                return "Invalid input"
    print(roman_dup)

# %%
test_dict = {
    0:'Invalid input',
    "":'Empty string',
    'LM':'Invalid input',
    'ABC':'Invalid input',
    'IIII':'Invalid input',
    'i':1,
    'I':1,
    'V':5,
    'IX':9,
    'X':10,
    'XL':40,
    'L':50,
    'XC':90,
    'C':100,
    'cL':140,
    'CDLVII':457,
    'DCCC':800,
    'CM':900,
    'MCDXCIV':1494,
    'MMMCDLVII':3457
}

# %%
def test(test_dict):
    passed = 0
    for key in test_dict:
        output = roman_to_num_converter(key)
        if output == test_dict[key]:
            print("Roman numeral: {}\nYour output: {}\nExpected output: {}\nRemark: PASSED".format(key, output, test_dict[key]))
            print()
            passed += 1
        else:
            print("Roman numeral: {}\nYour output: {}\nExpected output: {}\nRemark: FAILED".format(key, output, test_dict[key]))
            print()
        
    print("Overall summary: {} out of {} tests passed".format(passed, len(test_dict)))
    return

# %%
test(test_dict)
# Out:
# 0
# Roman numeral: 0
# Your output: Invalid input
# Expected output: Invalid input
# Remark: PASSED
#
#
# Roman numeral:
# Your output: Empty string
# Expected output: Empty string
# Remark: PASSED
#
# LM
# LM
# Roman numeral: LM
# Your output: 1000
# Expected output: Invalid input
# Remark: FAILED
#
# ABC
# ABC
# Roman numeral: ABC
# Your output: Invalid input
# Expected output: Invalid input
# Remark: PASSED
#
# IIII
# IIII
# Roman numeral: IIII
# Your output: Invalid input
# Expected output: Invalid input
# Remark: PASSED
#
# i
# I
# Roman numeral: i
# Your output: 1
# Expected output: 1
# Remark: PASSED
#
# I
# I
# Roman numeral: I
# Your output: 1
# Expected output: 1
# Remark: PASSED
#
# V
# V
# Roman numeral: V
# Your output: 5
# Expected output: 5
# Remark: PASSED
#
# IX
# IX
# Roman numeral: IX
# Your output: 1
# Expected output: 9
# Remark: FAILED
#
# X
# X
# Roman numeral: X
# Your output: 10
# Expected output: 10
# Remark: PASSED
#
# XL
# XL
# Roman numeral: XL
# Your output: 10
# Expected output: 40
# Remark: FAILED
#
# L
# L
# Roman numeral: L
# Your output: 50
# Expected output: 50
# Remark: PASSED
#
# XC
# XC
# Roman numeral: XC
# Your output: 10
# Expected output: 90
# Remark: FAILED
#
# C
# C
# Roman numeral: C
# Your output: 100
# Expected output: 100
# Remark: PASSED
#
# cL
# CL
# Roman numeral: cL
# Your output: 100
# Expected output: 140
# Remark: FAILED
#
# CDLVII
# CDLVII
# Roman numeral: CDLVII
# Your output: Invalid input
# Expected output: 457
# Remark: FAILED
#
# DCCC
# DCCC
# Roman numeral: DCCC
# Your output: Invalid input
# Expected output: 800
# Remark: FAILED
#
# CM
# CM
# Roman numeral: CM
# Your output: 1000
# Expected output: 900
# Remark: FAILED
#
# MCDXCIV
# MCDXCIV
# Roman numeral: MCDXCIV
# Your output: Invalid input
# Expected output: 1494
# Remark: FAILED
#
# MMMCDLVII
# MMMCDLVII
# Roman numeral: MMMCDLVII
# Your output: Invalid input
# Expected output: 3457
# Remark: FAILED
#
# Overall summary: 10 out of 20 tests passed

# %%
new = [1,2,2,3,4,5,5]
a = {1,2,3,4,5,6}
if set(new).issubset(a):
    print(5)
print(new)
# Out:
# 5
# [1, 2, 2, 3, 4, 5, 5]
